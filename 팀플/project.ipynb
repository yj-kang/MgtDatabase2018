# %%
import pandas as pd

# %%
health = pd.read_csv("health.csv", encoding = "utf-8")
health.head()
# Out:
#     지역  현재흡연율  현재흡연자의 금연시도율  고위험음주율  스트레스 인지율
# 0  종로구   20.4          35.2    20.1      25.4
# 1   중구   22.2          26.9    20.3      28.6
# 2  용산구   19.5          31.9    18.9      28.7
# 3  성동구   20.5          39.3    16.2      28.4
# 4  광진구   19.4          30.9    17.0      30.4

# %%
number = pd.read_csv('number.csv', encoding ='utf-8')
number
# Out:
#       구분          계       1인가구     2인가구     3인가구     4인가구    5인 가구    6인가구  \
# 0     합계  3,784,705  1,138,860  931,262  816,946  686,469  163,555  37,153
# 1    종로구     60,786     22,835   14,974   11,060    8,712    2,397     618
# 2     중구     51,503     19,671   13,086    9,453    6,844    1,836     480
# 3    용산구     90,164     31,641   23,505   17,580   13,121    3,327     780
# 4    성동구    116,401     37,074   28,668   24,655   19,874    4,636   1,164
# 5    광진구    146,196     53,169   33,221   28,757   24,040    5,430   1,202
# 6   동대문구    145,179     52,650   34,094   27,768   22,627    6,011   1,584
# 7    중랑구    157,571     45,717   40,865   34,515   27,503    6,971   1,569
# 8    성북구    174,370     54,117   41,498   36,906   31,578    7,791   1,915
# 9    강북구    125,580     36,668   33,636   27,243   20,969    5,386   1,294
# 10   도봉구    125,384     28,296   33,279   30,449   25,702    5,900   1,375
# ...

# %%
number['1인가구비율'] = number['1인가구'] + number['계']
number
# Out:
#       구분          계       1인가구     2인가구     3인가구     4인가구    5인 가구    6인가구  \
# 0     합계  3,784,705  1,138,860  931,262  816,946  686,469  163,555  37,153
# 1    종로구     60,786     22,835   14,974   11,060    8,712    2,397     618
# 2     중구     51,503     19,671   13,086    9,453    6,844    1,836     480
# 3    용산구     90,164     31,641   23,505   17,580   13,121    3,327     780
# 4    성동구    116,401     37,074   28,668   24,655   19,874    4,636   1,164
# 5    광진구    146,196     53,169   33,221   28,757   24,040    5,430   1,202
# 6   동대문구    145,179     52,650   34,094   27,768   22,627    6,011   1,584
# 7    중랑구    157,571     45,717   40,865   34,515   27,503    6,971   1,569
# 8    성북구    174,370     54,117   41,498   36,906   31,578    7,791   1,915
# 9    강북구    125,580     36,668   33,636   27,243   20,969    5,386   1,294
# 10   도봉구    125,384     28,296   33,279   30,449   25,702    5,900   1,375
# ...
